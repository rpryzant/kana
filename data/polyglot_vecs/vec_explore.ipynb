# %%
import pickle

# %%
a = pickle.load(open('polyglot-en.pkl'))

# %%
print len(a)
print len(a[0])
print len(a[1])
print len(a[1][0])
# Out:
# 2
# 100004
# 100004
# 64

# %%
a = pickle.load(open('polyglot-ja.pkl'))

# %%
print len(a)
print len(a[0])
print len(a[1])
print len(a[1][0])
# Out:
# 2
# 145004
# 145004
# 64

# %%
a[0]
# Out:
# (u'</S>',
#  u'<UNK>',
#  u'<PAD>',
#  u'<S>',
#  u'#',
#  u'\u5e74',
#  u'####',
#  u'##',
#  u'\u6708',
#  u'\u65e5',
#  u'###',
#  u'\u7684',
#  u'\u4eba',
#  u'\u8005',
#  u'\u65e5\u672c',
#  u'\u7b2c',
#  u'\u5f8c',
#  u'\u5e02',
#  u'\u884c\u3046',
#  u'\u770c',
#  u'\u95a2\u9023',
#  u'\u4e2d',
#  u'\u5916\u90e8',
#  u'\u30ea\u30f3\u30af',
#  u'\u99c5',
#  u'\u9805\u76ee',
#  u'\u304a\u308b',
#  u'\u73fe\u5728',
#  u'\u4e00',
#  u'\u5bb6',
#  u'\u5927\u5b66',
#  u'\u6642',
#  u'\u653e\u9001',
#  u'\u5316',
#  u'\u4f5c\u54c1',
#  u'\u6642\u4ee3',
#  u'\u90e8',
#  u'\u753a',
#  u'\u8ecd',
#  u'\u7dda',
#  u'\u5927',
#  u'\u5834\u5408',
#  u'\u540d',
#  u'\u811a\u6ce8',
#  u'\u6027',
#  u'\u4e0a',
#  u'\u56fd',
#  u'\u672c',
#  u'\u591a\u3044',
#  u'\u547c\u3076',
#  u'\u5dde',
#  u'\u4e16\u754c',
#  u'\u4e8c',
#  u'\u9593',
#  u'\u4f1a',
#  u'\u4e3b',
#  u'\u56de',
#  u'\u6771\u4eac',
#  u'\u4f7f\u7528',
#  u'\u6982\u8981',
#  u'\u6301\u3064',
#  u'\u6570',
#  u'\u756a\u7d44',
# ...
